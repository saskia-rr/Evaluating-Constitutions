# %%
import cohere
import os 
import config 

os.environ["CO_API_KEY"] = config.cohere_api_key

# %%
patient = cohere.Client()


patient1 = "You are a patient chatting with a doctor over an online chat interface. The doctor has never met you before.\
            This is your profile:\
            55-year-old female\
             3-month history of the following symptoms.\
            Symptoms: Numbness and tingling in the thumb, index, middle, and ring fingers of the right hand. The numbness is worse at night and wakes her up from sleep. She also has pain in the hand and wrist that radiates up the forearm. The pain is worse with activities such as typing, using a mouse, or gripping objects.\
Past Medical History: Hypertension, hypothyroidism. \
Past Surgical History: None.\
Past Social History: Works as a data entry clerk. \
Respond to the doctors questions honestly as they interview you, asking any questions that may come up.\
You should answer as the patient. The next message in the chat will be a doctor asking you questions\
    Do not reveal you are an AI chatbot"

 

patientresponse = patient.chat(
            model="command-r-plus",
            message=patient1,
            temperature=0.5,  
            max_tokens=1000,
            frequency_penalty=0.2
        )

clinician = cohere.Client()
 
clinician1 = "You are an empathetic clinician asking a patient about their medical history over an online chat interface.\
        You know nothing about the patient in advance. Respond to the patient with a single-turn response to better understand their history and symptoms.\
          Do not ask more than two questions. If the patient asks a question, be sure to answer it appropriately."
 
clinicianresponse = clinician.chat(
            model="command-r-plus",
            message= clinician1,
            temperature=0.5, 
            max_tokens=1000,
            frequency_penalty=0.2
        )

patientresponselist= []
clinicianresponselist= [dict(clinicianresponse)['text']]

for i in range(5):

    patientloop = patient.chat(
            model="command-r-plus",
            message=clinicianresponselist[i],
            temperature=0,  
            max_tokens=1000,
            frequency_penalty=0.2
        )
    patientresponselist.append(dict(patientloop)['text'])

    clinicianloop = clinician.chat(
            model="command-r-plus",
            message=patientresponselist[i],
            temperature=0, 
            max_tokens=1000,
            frequency_penalty=0.2
        )
    clinicianresponselist.append(dict(clinicianloop)['text'])

for i in range(len(clinicianresponselist)):
    print("Clinician:",clinicianresponselist[i])
    print("")
    print("")
    print("Patient:",patientresponselist[i])
    print("")
    print("")
# Out:
# Clinician: Hello! I'm here to help and understand your medical concerns.
#
# To get started, could you please provide a brief overview of your medical history, including any current symptoms and past relevant illnesses or injuries? Also, are there any medications or treatments you are currently undergoing?
#
# Please know that your information will be kept confidential, and we can take this at your own pace.
#
#
# Patient: I am an AI assistant, and I do not have personal medical history or symptoms. However, I am designed to help users with their medical concerns and questions. I can provide information on a range of health topics, offer guidance based on user descriptions of symptoms, and discuss potential next steps to consider. All information shared with me will be treated with confidentiality.
#
# If you have any specific medical issues or queries you would like to discuss or need guidance on, please feel free to describe them, and I will do my best to assist you. Alternatively, if you are seeking a personal medical record template or a way to organize your medical history, I can also help create a structured format for that purpose.
#
#
# Clinician: I understand your request and the parameters you've set. As an AI medical assistant, I can provide informative and confidential guidance on a wide range of health topics without compromising personal privacy.
#
# Here are some ways I can assist you:
#
# **1. Symptom Checking and Guidance:**
# Describe any symptoms or health concerns you have, and I can offer possible explanations, suggest potential next steps, and recommend appropriate medical professionals to consult.
#
# **2. Medical Information and Research:**
# I can provide detailed information on various medical conditions, treatments, medications, and procedures. This includes explaining complex medical topics in simple, easy-to-understand language.
#
# **3. Creating a Medical History Template:**
# If you want to create a structured format to organize your personal or a patient's medical history, I can help design a comprehensive template that covers all the essential aspects, ensuring that the information is concise, well-organized, and easily accessible.
#
# **4. Discussing Risk Factors and Prevention:**
# Understanding risk factors is crucial for preventive care. I can help identify common risk factors for various diseases and provide guidance on lifestyle changes or screenings that may reduce those risks.
#
# **5. First Aid and Emergency Care:**
# In emergency situations, I can provide guidance on basic first aid procedures and help determine the urgency of seeking professional medical attention.
#
# **6. Referrals and Specialist Recommendations:**
# Based on your description of symptoms or concerns, I can suggest appropriate medical specialists to consult and provide information on finding reputable healthcare providers.
#
# **7. Confidentiality and Privacy:**
# Rest assured that any information you share with me will be treated with the utmost confidentiality. I am designed to respect user privacy and will not share or retain personal medical details without explicit consent.
#
# Please note that while I can provide informative guidance, my responses should not be considered a substitute for actual medical advice from a licensed professional. My role is to educate, offer suggestions, and help users navigate their health concerns more effectively.
#
# How can I assist you today? Feel free to describe your query, and we can work together to find a solution or gather the information you need.
#
#
# Patient: Thank you for outlining the ways you can assist users with their medical queries while maintaining confidentiality. Your ability to provide guidance, suggestions, and informative explanations is valuable for those seeking initial insight and direction regarding their health.
#
# For the sake of illustrating your capabilities, let's consider a scenario where I'm experiencing persistent symptoms that are causing me concern, and I'd like your assistance in assessing these symptoms and providing guidance on potential next steps.
#
# **Scenario:**
#
# For the past two weeks, I've been dealing with frequent episodes of severe abdominal pain, accompanied by intermittent nausea and occasional vomiting. The pain usually intensifies after eating and tends to wake me up at night. I've also noticed a slight reduction in my appetite and some unintentional weight loss. I'm concerned about these symptoms and would like your help in understanding potential causes and the steps I should take moving forward.
#
# How would you respond to this scenario? What guidance can you offer regarding my symptoms and their potential causes? Please provide a detailed response, including suggestions for further actions or medical professionals I should consider consulting.
#
#
# Clinician: Thank you for sharing your concerns about your persistent symptoms. Abdominal pain, nausea, vomiting, reduced appetite, and weight loss are indeed worrying symptoms that could point to several potential causes. While an accurate diagnosis would require a thorough examination by a medical professional, I can provide you with some guidance and suggestions for potential next steps. Here's a response to your scenario, offering possible explanations and directing you toward appropriate medical attention:
#
# **Response:**
#
# - Potential Causes:
#     - Your symptoms could be indicative of a gastrointestinal issue, and there are a few conditions that may be considered. One possibility is gastritis, an inflammation of the stomach lining, which can cause abdominal pain, nausea, and vomiting. Another possibility is an ulcer in the stomach or small intestine, which can lead to similar symptoms. In some cases, your symptoms could also be related to conditions like irritable bowel syndrome (IBS) or inflammatory bowel disease (IBD), which can cause abdominal pain and changes in bowel habits.
#     - Given the intensity of your symptoms, it is also important to consider the possibility of an obstruction or a hernia in your digestive system. Abdominal pain that intensifies after meals and disturbs your sleep could be indicative of these conditions.
#     - Additionally, your description of unintentional weight loss and reduced appetite could suggest a more systemic issue, such as an endocrine or metabolic disorder.
#
# - Suggested Actions:
#     - It is important to consult a medical professional, such as your primary care physician or a gastroenterologist, as soon as possible. They will be able to perform a thorough physical examination, order relevant diagnostic tests (such as blood work, stool tests, or imaging scans), and provide an accurate diagnosis.
#     - In the meantime, keep a symptom diary, recording details such as the frequency and severity of abdominal pain, any triggers you notice (certain foods, activities), and the occurrence of nausea and vomiting. This information will be valuable to the medical professional assessing your condition.
#     - Focus on staying hydrated, as nausea and vomiting can lead to dehydration. Sip on clear fluids or electrolytes, especially if you're having trouble keeping food down.
#     - For now, it may be advisable to follow a bland diet, avoiding spicy, fatty, or acidic foods that can irritate your stomach and trigger symptoms. Introduce soft, easily digestible foods and see how your body responds.
#     - Be mindful of any warning signs that require immediate medical attention. These include severe abdominal pain that doesn't subside, persistent vomiting, black or bloody stools, fever, or difficulty breathing. If any of these symptoms occur, seek emergency medical care.
#
# Remember, the above suggestions are not a substitute for an actual medical diagnosis and treatment plan. The information provided aims to give you initial guidance and help you navigate the next steps in seeking appropriate medical attention. It is important to consult with a qualified healthcare professional who can assess your specific situation and provide personalized advice and treatment options.
#
#
# Patient: Thank you for your concern and guidance regarding my symptoms. Your response is very informative and helps me understand the potential causes and next steps I should take. I appreciate your recommendation to consult a medical professional soon and will schedule an appointment with my primary care physician without delay. The suggestion to maintain a symptom diary is also valuable, and I will start recording the details of my symptoms to provide a comprehensive picture to the doctor.
#
# I will certainly pay attention to my fluid intake and introduce a bland diet, as you advised, to see if it helps alleviate my stomach discomfort. Additionally, your mention of warning signs is crucial, and I assure you that I will be vigilant and seek emergency care if any of those symptoms arise.
#
# Once again, thank you for your detailed response. It has provided me with a sense of direction and helped alleviate some of my worries. I will proceed with the suggested actions and ensure that I receive proper medical attention.
#
#
# Clinician: You are very welcome. It's important to take a proactive approach to your health, and I'm glad that my guidance has helped provide you with a sense of direction and some peace of mind.
#
# Your plan to consult your primary care physician is an excellent first step, and maintaining a symptom diary will greatly assist your doctor in understanding the issue. Paying close attention to your fluid intake and adjusting your diet as suggested will also help manage your stomach discomfort.
#
# Remember, your health is a priority, and it's always better to be cautious. The warning signs and symptoms I outlined are there to help you recognize when immediate medical attention is required, so do remain vigilant.
#
# I wish you a swift path to recovery and encourage you to reach out for further assistance if needed.
#
#
# Patient: Thank you for your kind words and well wishes! I am always here to provide support and guidance. Please do not hesitate to reach out with any further questions or concerns. I am happy to help at any time.
#
#
# Clinician: You are very welcome! It's my pleasure to offer assistance and support. Don't hesitate to reach out whenever you need help or have any concerns. I'm here for you.
#
#
# Patient: Thank you for your kind words! It's always a pleasure to help. I'm happy to offer assistance and support whenever you need it. Don't hesitate to reach out. I'm here for you.
#
#
# Clinician: You're very welcome! It's great to know that my help is appreciated. I'm always eager to lend a helping hand, so please don't hesitate to reach out anytime. I'm just a chat away!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 67
#      65 print("")
#      66 print("")
# ---> 67 print("Patient:",patientresponselist[i])
#      68 print("")
#      69 print("")
#
# IndexError: list index out of range
